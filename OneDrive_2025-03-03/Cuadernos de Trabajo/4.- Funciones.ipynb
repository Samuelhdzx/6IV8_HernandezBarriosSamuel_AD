# %% [markdown]
# # 4.- Funciones

# %% [markdown]
# ## 4.2.- Función def

# %% [markdown]
# Vamos a comenzar creando una funcion que tome un número y devuelva su raiz cuadrada

# %%
def raiz_cuad(número):
    return número**(1/2)
raiz_cuad(49)
# Out:
# 7.0

# %%
raiz_cuad?
# Out:
# Signature: raiz_cuad(número)
# Docstring: <no docstring>
# File:      c:\users\herna\appdata\local\temp\ipykernel_14884\3202591709.py
# Type:      function

# %% [markdown]
# Las funciones también las podemos llamar desde otras expresiones como print

# %%
print(raiz_cuad)
# Out:
# <function raiz_cuad at 0x000001517A8F5260>

# %% [markdown]
# Muchas funciones podemos ? para saber como se usa la función

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %% [markdown]
# #### Por tu cuenta
#
# Define una función que calcule la raiz cubica de un numero dado

# %%
def raiz_cuad(número):
    return número**(1/3)
raiz_cuad(27)
# Out:
# 3.0

# %% [markdown]
# ## 4.3.- Funciones con Múltiples Parámetros

# %% [markdown]
# Ahora armaremos una función usando IF que nos dice cual es la raiz cuadrada más grande de 3 números

# %%
def raiz_min (num1,num2,num3):
    r_num1=num1**(1/2)
    r_num2=num2**(1/2)
    r_num3=num3**(1/2)
    raiz_min=r_num1
    if r_num2<raiz_min:
        raiz_min=r_num2
    if r_num3<raiz_min:
        raiz_min=r_num3
    return raiz_min

raiz_min(9,25,4)
# Out:
# 2.0

# %%
raiz_min(74,73,75)
# Out:
# 8.54400374531753

# %% [markdown]
# Por si las dudas, esto se podría haber simplificado usando Max y Min

# %%
def raiz_min(num1, num2, num3):
    return min(num1**(1/2), num2**(1/2), num3**(1/2))

raiz_min(9, 25, 4)
# Out:
# 2.0

# %%
raiz_min(74,73,75)
# Out:
# 8.54400374531753

# %% [markdown]
# #### Por tu cuenta
#
# Llama la función max con la lista 15,82,13,55 como argumento, yluego la min con la palabara amarillo como argumento

# %% [markdown]
# ## 4.4.- Números aleatorios

# %% [markdown]
# Vamos a simular el lanzamiento de una moneda (cara o cruz), usemos la biblioteca random y simulemos 10 tiros

# %%
import random 

for tirada in range(10):
    print(random.randint(0,2), end=" ")
# Out:
# 0 2 0 1 1 0 1 1 0 1

# %%
import random 

for tirada in range(10):
    print(random.randint(0,2), end=" ")
# Out:
# 0 1 1 1 1 0 2 1 1 0

# %% [markdown]
# Ejecutalo de nuevo, checa como ahora tenemos diferentes resultados

# %% [markdown]
# Ahora vamos a escribir un código que simule el lanzamiento de una moneda 100,000 veces. No vamos a mostrar 100,000 resultados, solo una pequeña tabla con todas las caras y todas la cruces

# %%
import random 

frecuencias_unos = 0
frecuencias_ceros = 0

for tirada in range(10000):
    resultado = random.randrange(0,2)
    if resultado == 1:
        frecuencias_unos += 1
    else:
        frecuencias_ceros += 1
    print(f'1=Cara,  0=Águila {" Frecuencia":>13}')
    print(f'{1:>14}{frecuencias_unos:>13}')
    print(f'{0:>14}{frecuencias_ceros:>13}')
# Out:
# 1=Cara,  0=Águila    Frecuencia
#              1            0
#              0            1
# 1=Cara,  0=Águila    Frecuencia
#              1            0
#              0            2
# 1=Cara,  0=Águila    Frecuencia
#              1            1
#              0            2
# 1=Cara,  0=Águila    Frecuencia
#              1            1
#              0            3
# 1=Cara,  0=Águila    Frecuencia
#              1            2
#              0            3
# 1=Cara,  0=Águila    Frecuencia
#              1            2
#              0            4
# 1=Cara,  0=Águila    Frecuencia
#              1            2
#              0            5
# 1=Cara,  0=Águila    Frecuencia
#              1            3
#              0            5
# 1=Cara,  0=Águila    Frecuencia
#              1            4
#              0            5
# 1=Cara,  0=Águila    Frecuencia
#              1            4
#              0            6
# 1=Cara,  0=Águila    Frecuencia
#              1            4
#              0            7
# 1=Cara,  0=Águila    Frecuencia
#              1            4
#              0            8
# 1=Cara,  0=Águila    Frecuencia
#              1            4
#              0            9
# 1=Cara,  0=Águila    Frecuencia
#              1            4
#              0           10
# 1=Cara,  0=Águila    Frecuencia
#              1            5
#              0           10
# 1=Cara,  0=Águila    Frecuencia
#              1            5
#              0           11
# 1=Cara,  0=Águila    Frecuencia
#              1            5
#              0           12
# 1=Cara,  0=Águila    Frecuencia
#              1            5
#              0           13
# 1=Cara,  0=Águila    Frecuencia
#              1            6
#              0           13
# 1=Cara,  0=Águila    Frecuencia
#              1            7
#              0           13
# 1=Cara,  0=Águila    Frecuencia
#              1            8
#              0           13
# 1=Cara,  0=Águila    Frecuencia
#              1            9
#              0           13
# 1=Cara,  0=Águila    Frecuencia
#              1            9
#              0           14
# 1=Cara,  0=Águila    Frecuencia
#              1           10
#              0           14
# 1=Cara,  0=Águila    Frecuencia
#              1           10
#              0           15
# 1=Cara,  0=Águila    Frecuencia
#              1           10
#              0           16
# 1=Cara,  0=Águila    Frecuencia
#              1           11
#              0           16
# 1=Cara,  0=Águila    Frecuencia
#              1           11
#              0           17
# 1=Cara,  0=Águila    Frecuencia
#              1           11
#              0           18
# 1=Cara,  0=Águila    Frecuencia
#              1           12
#              0           18
# 1=Cara,  0=Águila    Frecuencia
#              1           12
#              0           19
# 1=Cara,  0=Águila    Frecuencia
#              1           12
#              0           20
# 1=Cara,  0=Águila    Frecuencia
#              1           12
#              0           21
# 1=Cara,  0=Águila    Frecuencia
#              1           13
#              0           21
# 1=Cara,  0=Águila    Frecuencia
#              1           14
#              0           21
# 1=Cara,  0=Águila    Frecuencia
#              1           15
#              0           21
# 1=Cara,  0=Águila    Frecuencia
#              1           16
#              0           21
# 1=Cara,  0=Águila    Frecuencia
#              1           16
#              0           22
# 1=Cara,  0=Águila    Frecuencia
#              1           17
#              0           22
# 1=Cara,  0=Águila    Frecuencia
#              1           17
#              0           23
# 1=Cara,  0=Águila    Frecuencia
#              1           17
#              0           24
# 1=Cara,  0=Águila    Frecuencia
#              1           18
#              0           24
# 1=Cara,  0=Águila    Frecuencia
#              1           18
#              0           25
# 1=Cara,  0=Águila    Frecuencia
#              1           18
#              0           26
# 1=Cara,  0=Águila    Frecuencia
#              1           18
#              0           27
# 1=Cara,  0=Águila    Frecuencia
#              1           18
#              0           28
# 1=Cara,  0=Águila    Frecuencia
#              1           18
#              0           29
# 1=Cara,  0=Águila    Frecuencia
#              1           18
#              0           30
# 1=Cara,  0=Águila    Frecuencia
#              1           18
#              0           31
# 1=Cara,  0=Águila    Frecuencia
#              1           18
#              0           32
# 1=Cara,  0=Águila    Frecuencia
#              1           19
#              0           32
# 1=Cara,  0=Águila    Frecuencia
#              1           19
#              0           33
# 1=Cara,  0=Águila    Frecuencia
#              1           19
#              0           34
# 1=Cara,  0=Águila    Frecuencia
#              1           20
#              0           34
# 1=Cara,  0=Águila    Frecuencia
#              1           21
#              0           34
# 1=Cara,  0=Águila    Frecuencia
#              1           22
#              0           34
# 1=Cara,  0=Águila    Frecuencia
#              1           23
#              0           34
# 1=Cara,  0=Águila    Frecuencia
#              1           23
#              0           35
# 1=Cara,  0=Águila    Frecuencia
#              1           24
#              0           35
# 1=Cara,  0=Águila    Frecuencia
#              1           24
#              0           36
# 1=Cara,  0=Águila    Frecuencia
#              1           24
#              0           37
# 1=Cara,  0=Águila    Frecuencia
#              1           24
#              0           38
# 1=Cara,  0=Águila    Frecuencia
#              1           25
#              0           38
# 1=Cara,  0=Águila    Frecuencia
#              1           26
#              0           38
# 1=Cara,  0=Águila    Frecuencia
#              1           26
#              0           39
# 1=Cara,  0=Águila    Frecuencia
#              1           26
#              0           40
# 1=Cara,  0=Águila    Frecuencia
#              1           27
#              0           40
# 1=Cara,  0=Águila    Frecuencia
#              1           27
#              0           41
# 1=Cara,  0=Águila    Frecuencia
#              1           28
#              0           41
# 1=Cara,  0=Águila    Frecuencia
#              1           28
#              0           42
# 1=Cara,  0=Águila    Frecuencia
#              1           29
#              0           42
# 1=Cara,  0=Águila    Frecuencia
#              1           30
#              0           42
# 1=Cara,  0=Águila    Frecuencia
#              1           31
#              0           42
# 1=Cara,  0=Águila    Frecuencia
#              1           31
#              0           43
# 1=Cara,  0=Águila    Frecuencia
#              1           32
#              0           43
# 1=Cara,  0=Águila    Frecuencia
#              1           33
#              0           43
# 1=Cara,  0=Águila    Frecuencia
#              1           33
#              0           44
# 1=Cara,  0=Águila    Frecuencia
#              1           33
#              0           45
# 1=Cara,  0=Águila    Frecuencia
#              1           33
#              0           46
# 1=Cara,  0=Águila    Frecuencia
#              1           34
#              0           46
# 1=Cara,  0=Águila    Frecuencia
#              1           34
#              0           47
# 1=Cara,  0=Águila    Frecuencia
#              1           34
#              0           48
# 1=Cara,  0=Águila    Frecuencia
#              1           35
#              0           48
# 1=Cara,  0=Águila    Frecuencia
#              1           36
#              0           48
# 1=Cara,  0=Águila    Frecuencia
#              1           37
#              0           48
# 1=Cara,  0=Águila    Frecuencia
#              1           38
#              0           48
# 1=Cara,  0=Águila    Frecuencia
#              1           39
#              0           48
# 1=Cara,  0=Águila    Frecuencia
#              1           40
#              0           48
# 1=Cara,  0=Águila    Frecuencia
#              1           41
#              0           48
# 1=Cara,  0=Águila    Frecuencia
#              1           41
#              0           49
# 1=Cara,  0=Águila    Frecuencia
#              1           41
#              0           50
# 1=Cara,  0=Águila    Frecuencia
#              1           41
#              0           51
# 1=Cara,  0=Águila    Frecuencia
#              1           42
#              0           51
# 1=Cara,  0=Águila    Frecuencia
#              1           42
#              0           52
# 1=Cara,  0=Águila    Frecuencia
#              1           43
#              0           52
# 1=Cara,  0=Águila    Frecuencia
#              1           44
#              0           52
# 1=Cara,  0=Águila    Frecuencia
#              1           45
#              0           52
# 1=Cara,  0=Águila    Frecuencia
#              1           45
#              0           53
# 1=Cara,  0=Águila    Frecuencia
#              1           46
#              0           53
# 1=Cara,  0=Águila    Frecuencia
#              1           47
#              0           53
# 1=Cara,  0=Águila    Frecuencia
#              1           48
#              0           53
# 1=Cara,  0=Águila    Frecuencia
#              1           48
#              0           54
# 1=Cara,  0=Águila    Frecuencia
#              1           49
#              0           54
# 1=Cara,  0=Águila    Frecuencia
#              1           50
#              0           54
# 1=Cara,  0=Águila    Frecuencia
#              1           51
#              0           54
# 1=Cara,  0=Águila    Frecuencia
#              1           51
#              0           55
# 1=Cara,  0=Águila    Frecuencia
#              1           52
#              0           55
# 1=Cara,  0=Águila    Frecuencia
#              1           53
#              0           55
# 1=Cara,  0=Águila    Frecuencia
#              1           53
#              0           56
# 1=Cara,  0=Águila    Frecuencia
#              1           53
#              0           57
# 1=Cara,  0=Águila    Frecuencia
#              1           54
#              0           57
# 1=Cara,  0=Águila    Frecuencia
#              1           55
#              0           57
# 1=Cara,  0=Águila    Frecuencia
#              1           56
#              0           57
# 1=Cara,  0=Águila    Frecuencia
#              1           57
#              0           57
# 1=Cara,  0=Águila    Frecuencia
#              1           57
#              0           58
# 1=Cara,  0=Águila    Frecuencia
#              1           57
#              0           59
# 1=Cara,  0=Águila    Frecuencia
#              1           58
#              0           59
# 1=Cara,  0=Águila    Frecuencia
#              1           58
#              0           60
# 1=Cara,  0=Águila    Frecuencia
#              1           59
#              0           60
# 1=Cara,  0=Águila    Frecuencia
#              1           59
#              0           61
# 1=Cara,  0=Águila    Frecuencia
#              1           59
#              0           62
# 1=Cara,  0=Águila    Frecuencia
#              1           59
#              0           63
# 1=Cara,  0=Águila    Frecuencia
#              1           60
#              0           63
# 1=Cara,  0=Águila    Frecuencia
#              1           60
#              0           64
# 1=Cara,  0=Águila    Frecuencia
#              1           60
#              0           65
# 1=Cara,  0=Águila    Frecuencia
#              1           61
#              0           65
# 1=Cara,  0=Águila    Frecuencia
#              1           62
#              0           65
# 1=Cara,  0=Águila    Frecuencia
#              1           62
#              0           66
# 1=Cara,  0=Águila    Frecuencia
#              1           62
#              0           67
# 1=Cara,  0=Águila    Frecuencia
#              1           63
#              0           67
# 1=Cara,  0=Águila    Frecuencia
#              1           64
#              0           67
# 1=Cara,  0=Águila    Frecuencia
#              1           65
#              0           67
# 1=Cara,  0=Águila    Frecuencia
#              1           66
#              0           67
# 1=Cara,  0=Águila    Frecuencia
#              1           67
#              0           67
# 1=Cara,  0=Águila    Frecuencia
#              1           68
#              0           67
# 1=Cara,  0=Águila    Frecuencia
#              1           69
#              0           67
# 1=Cara,  0=Águila    Frecuencia
#              1           69
#              0           68
# 1=Cara,  0=Águila    Frecuencia
#              1           70
#              0           68
# 1=Cara,  0=Águila    Frecuencia
#              1           71
#              0           68
# 1=Cara,  0=Águila    Frecuencia
#              1           72
#              0           68
# 1=Cara,  0=Águila    Frecuencia
#              1           72
#              0           69
# 1=Cara,  0=Águila    Frecuencia
#              1           72
#              0           70
# 1=Cara,  0=Águila    Frecuencia
#              1           72
#              0           71
# 1=Cara,  0=Águila    Frecuencia
#              1           73
#              0           71
# 1=Cara,  0=Águila    Frecuencia
#              1           73
#              0           72
# 1=Cara,  0=Águila    Frecuencia
#              1           73
#              0           73
# 1=Cara,  0=Águila    Frecuencia
#              1           73
#              0           74
# 1=Cara,  0=Águila    Frecuencia
#              1           74
#              0           74
# 1=Cara,  0=Águila    Frecuencia
#              1           75
#              0           74
# 1=Cara,  0=Águila    Frecuencia
#              1           76
#              0           74
# 1=Cara,  0=Águila    Frecuencia
#              1           77
#              0           74
# 1=Cara,  0=Águila    Frecuencia
#              1           77
#              0           75
# 1=Cara,  0=Águila    Frecuencia
#              1           78
#              0           75
# 1=Cara,  0=Águila    Frecuencia
#              1           78
#              0           76
# 1=Cara,  0=Águila    Frecuencia
#              1           78
#              0           77
# 1=Cara,  0=Águila    Frecuencia
#              1           79
#              0           77
# 1=Cara,  0=Águila    Frecuencia
#              1           80
#              0           77
# 1=Cara,  0=Águila    Frecuencia
#              1           80
#              0           78
# 1=Cara,  0=Águila    Frecuencia
#              1           80
#              0           79
# 1=Cara,  0=Águila    Frecuencia
#              1           81
#              0           79
# 1=Cara,  0=Águila    Frecuencia
#              1           82
#              0           79
# 1=Cara,  0=Águila    Frecuencia
#              1           83
#              0           79
# 1=Cara,  0=Águila    Frecuencia
#              1           84
#              0           79
# 1=Cara,  0=Águila    Frecuencia
#              1           85
#              0           79
# 1=Cara,  0=Águila    Frecuencia
#              1           85
#              0           80
# 1=Cara,  0=Águila    Frecuencia
#              1           85
#              0           81
# 1=Cara,  0=Águila    Frecuencia
#              1           86
#              0           81
# 1=Cara,  0=Águila    Frecuencia
#              1           86
#              0           82
# 1=Cara,  0=Águila    Frecuencia
#              1           86
#              0           83
# 1=Cara,  0=Águila    Frecuencia
#              1           86
#              0           84
# 1=Cara,  0=Águila    Frecuencia
#              1           86
#              0           85
# 1=Cara,  0=Águila    Frecuencia
#              1           87
#              0           85
# 1=Cara,  0=Águila    Frecuencia
#              1           87
#              0           86
# 1=Cara,  0=Águila    Frecuencia
#              1           88
#              0           86
# 1=Cara,  0=Águila    Frecuencia
#              1           89
#              0           86
# 1=Cara,  0=Águila    Frecuencia
#              1           90
#              0           86
# 1=Cara,  0=Águila    Frecuencia
#              1           91
#              0           86
# 1=Cara,  0=Águila    Frecuencia
#              1           91
#              0           87
# 1=Cara,  0=Águila    Frecuencia
#              1           92
#              0           87
# 1=Cara,  0=Águila    Frecuencia
#              1           92
#              0           88
# 1=Cara,  0=Águila    Frecuencia
#              1           93
#              0           88
# 1=Cara,  0=Águila    Frecuencia
#              1           94
#              0           88
# 1=Cara,  0=Águila    Frecuencia
#              1           95
#              0           88
# 1=Cara,  0=Águila    Frecuencia
#              1           95
#              0           89
# 1=Cara,  0=Águila    Frecuencia
#              1           95
#              0           90
# 1=Cara,  0=Águila    Frecuencia
#              1           95
#              0           91
# 1=Cara,  0=Águila    Frecuencia
#              1           95
#              0           92
# 1=Cara,  0=Águila    Frecuencia
#              1           96
#              0           92
# 1=Cara,  0=Águila    Frecuencia
#              1           97
#              0           92
# 1=Cara,  0=Águila    Frecuencia
#              1           97
#              0           93
# 1=Cara,  0=Águila    Frecuencia
#              1           97
#              0           94
# 1=Cara,  0=Águila    Frecuencia
#              1           97
#              0           95
# 1=Cara,  0=Águila    Frecuencia
#              1           98
#              0           95
# 1=Cara,  0=Águila    Frecuencia
#              1           98
#              0           96
# 1=Cara,  0=Águila    Frecuencia
#              1           98
#              0           97
# 1=Cara,  0=Águila    Frecuencia
#              1           99
#              0           97
# 1=Cara,  0=Águila    Frecuencia
#              1          100
#              0           97
# 1=Cara,  0=Águila    Frecuencia
#              1          101
#              0           97
# 1=Cara,  0=Águila    Frecuencia
#              1          102
#              0           97
# 1=Cara,  0=Águila    Frecuencia
#              1          102
#              0           98
# 1=Cara,  0=Águila    Frecuencia
#              1          103
#              0           98
# 1=Cara,  0=Águila    Frecuencia
#              1          104
#              0           98
# 1=Cara,  0=Águila    Frecuencia
#              1          104
#              0           99
# 1=Cara,  0=Águila    Frecuencia
#              1          104
#              0          100
# 1=Cara,  0=Águila    Frecuencia
#              1          105
#              0          100
# 1=Cara,  0=Águila    Frecuencia
#              1          105
#              0          101
# 1=Cara,  0=Águila    Frecuencia
#              1          105
#              0          102
# 1=Cara,  0=Águila    Frecuencia
#              1          106
#              0          102
# 1=Cara,  0=Águila    Frecuencia
#              1          106
#              0          103
# 1=Cara,  0=Águila    Frecuencia
#              1          106
#              0          104
# 1=Cara,  0=Águila    Frecuencia
#              1          107
#              0          104
# 1=Cara,  0=Águila    Frecuencia
#              1          107
#              0          105
# 1=Cara,  0=Águila    Frecuencia
#              1          108
#              0          105
# 1=Cara,  0=Águila    Frecuencia
#              1          109
#              0          105
# 1=Cara,  0=Águila    Frecuencia
#              1          109
#              0          106
# 1=Cara,  0=Águila    Frecuencia
#              1          109
#              0          107
# 1=Cara,  0=Águila    Frecuencia
#              1          110
#              0          107
# 1=Cara,  0=Águila    Frecuencia
#              1          111
#              0          107
# 1=Cara,  0=Águila    Frecuencia
#              1          112
#              0          107
# 1=Cara,  0=Águila    Frecuencia
#              1          113
#              0          107
# 1=Cara,  0=Águila    Frecuencia
#              1          113
#              0          108
# 1=Cara,  0=Águila    Frecuencia
#              1          113
#              0          109
# 1=Cara,  0=Águila    Frecuencia
#              1          113
#              0          110
# 1=Cara,  0=Águila    Frecuencia
#              1          114
#              0          110
# 1=Cara,  0=Águila    Frecuencia
#              1          115
#              0          110
# 1=Cara,  0=Águila    Frecuencia
#              1          115
#              0          111
# 1=Cara,  0=Águila    Frecuencia
#              1          115
#              0          112
# 1=Cara,  0=Águila    Frecuencia
#              1          116
#              0          112
# 1=Cara,  0=Águila    Frecuencia
#              1          116
#              0          113
# 1=Cara,  0=Águila    Frecuencia
#              1          117
#              0          113
# 1=Cara,  0=Águila    Frecuencia
#              1          118
#              0          113
# 1=Cara,  0=Águila    Frecuencia
#              1          118
#              0          114
# 1=Cara,  0=Águila    Frecuencia
#              1          118
#              0          115
# 1=Cara,  0=Águila    Frecuencia
#              1          119
#              0          115
# 1=Cara,  0=Águila    Frecuencia
#              1          120
#              0          115
# 1=Cara,  0=Águila    Frecuencia
#              1          120
#              0          116
# 1=Cara,  0=Águila    Frecuencia
#              1          121
#              0          116
# 1=Cara,  0=Águila    Frecuencia
#              1          121
#              0          117
# 1=Cara,  0=Águila    Frecuencia
#              1          122
#              0          117
# 1=Cara,  0=Águila    Frecuencia
#              1          123
#              0          117
# 1=Cara,  0=Águila    Frecuencia
#              1          124
#              0          117
# 1=Cara,  0=Águila    Frecuencia
#              1          124
#              0          118
# 1=Cara,  0=Águila    Frecuencia
#              1          124
#              0          119
# 1=Cara,  0=Águila    Frecuencia
#              1          124
#              0          120
# 1=Cara,  0=Águila    Frecuencia
#              1          124
#              0          121
# 1=Cara,  0=Águila    Frecuencia
#              1          125
#              0          121
# 1=Cara,  0=Águila    Frecuencia
#              1          126
#              0          121
# 1=Cara,  0=Águila    Frecuencia
#              1          126
#              0          122
# 1=Cara,  0=Águila    Frecuencia
#              1          126
#              0          123
# 1=Cara,  0=Águila    Frecuencia
#              1          127
#              0          123
# 1=Cara,  0=Águila    Frecuencia
#              1          128
#              0          123
# 1=Cara,  0=Águila    Frecuencia
#              1          128
#              0          124
# 1=Cara,  0=Águila    Frecuencia
#              1          129
#              0          124
# 1=Cara,  0=Águila    Frecuencia
#              1          130
#              0          124
# 1=Cara,  0=Águila    Frecuencia
#              1          131
#              0          124
# 1=Cara,  0=Águila    Frecuencia
#              1          131
#              0          125
# 1=Cara,  0=Águila    Frecuencia
#              1          131
#              0          126
# 1=Cara,  0=Águila    Frecuencia
#              1          131
#              0          127
# 1=Cara,  0=Águila    Frecuencia
#              1          131
#              0          128
# 1=Cara,  0=Águila    Frecuencia
#              1          131
#              0          129
# 1=Cara,  0=Águila    Frecuencia
#              1          132
#              0          129
# 1=Cara,  0=Águila    Frecuencia
#              1          132
#              0          130
# 1=Cara,  0=Águila    Frecuencia
#              1          133
#              0          130
# 1=Cara,  0=Águila    Frecuencia
#              1          133
#              0          131
# 1=Cara,  0=Águila    Frecuencia
#              1          134
#              0          131
# 1=Cara,  0=Águila    Frecuencia
#              1          135
#              0          131
# 1=Cara,  0=Águila    Frecuencia
#              1          135
#              0          132
# 1=Cara,  0=Águila    Frecuencia
#              1          135
#              0          133
# 1=Cara,  0=Águila    Frecuencia
#              1          135
#              0          134
# 1=Cara,  0=Águila    Frecuencia
#              1          136
#              0          134
# 1=Cara,  0=Águila    Frecuencia
#              1          137
#              0          134
# 1=Cara,  0=Águila    Frecuencia
#              1          138
#              0          134
# 1=Cara,  0=Águila    Frecuencia
#              1          138
#              0          135
# 1=Cara,  0=Águila    Frecuencia
#              1          138
#              0          136
# 1=Cara,  0=Águila    Frecuencia
#              1          139
#              0          136
# 1=Cara,  0=Águila    Frecuencia
#              1          140
#              0          136
# 1=Cara,  0=Águila    Frecuencia
#              1          140
#              0          137
# 1=Cara,  0=Águila    Frecuencia
#              1          140
#              0          138
# 1=Cara,  0=Águila    Frecuencia
#              1          140
#              0          139
# 1=Cara,  0=Águila    Frecuencia
#              1          140
#              0          140
# 1=Cara,  0=Águila    Frecuencia
#              1          140
#              0          141
# 1=Cara,  0=Águila    Frecuencia
#              1          140
#              0          142
# 1=Cara,  0=Águila    Frecuencia
#              1          141
#              0          142
# 1=Cara,  0=Águila    Frecuencia
#              1          142
#              0          142
# 1=Cara,  0=Águila    Frecuencia
#              1          143
#              0          142
# 1=Cara,  0=Águila    Frecuencia
#              1          143
#              0          143
# 1=Cara,  0=Águila    Frecuencia
#              1          143
#              0          144
# 1=Cara,  0=Águila    Frecuencia
#              1          143
#              0          145
# 1=Cara,  0=Águila    Frecuencia
#              1          143
#              0          146
# 1=Cara,  0=Águila    Frecuencia
#              1          143
#              0          147
# 1=Cara,  0=Águila    Frecuencia
#              1          143
#              0          148
# 1=Cara,  0=Águila    Frecuencia
#              1          144
#              0          148
# 1=Cara,  0=Águila    Frecuencia
#              1          145
#              0          148
# 1=Cara,  0=Águila    Frecuencia
#              1          146
#              0          148
# 1=Cara,  0=Águila    Frecuencia
#              1          146
#              0          149
# 1=Cara,  0=Águila    Frecuencia
#              1          146
#              0          150
# 1=Cara,  0=Águila    Frecuencia
#              1          146
#              0          151
# 1=Cara,  0=Águila    Frecuencia
#              1          147
#              0          151
# 1=Cara,  0=Águila    Frecuencia
#              1          147
#              0          152
# 1=Cara,  0=Águila    Frecuencia
#              1          148
#              0          152
# 1=Cara,  0=Águila    Frecuencia
#              1          148
#              0          153
# 1=Cara,  0=Águila    Frecuencia
#              1          149
#              0          153
# 1=Cara,  0=Águila    Frecuencia
#              1          150
#              0          153
# 1=Cara,  0=Águila    Frecuencia
#              1          151
#              0          153
# 1=Cara,  0=Águila    Frecuencia
#              1          151
#              0          154
# 1=Cara,  0=Águila    Frecuencia
#              1          151
#              0          155
# 1=Cara,  0=Águila    Frecuencia
#              1          152
#              0          155
# 1=Cara,  0=Águila    Frecuencia
#              1          153
#              0          155
# 1=Cara,  0=Águila    Frecuencia
#              1          154
#              0          155
# 1=Cara,  0=Águila    Frecuencia
#              1          154
#              0          156
# 1=Cara,  0=Águila    Frecuencia
#              1          155
#              0          156
# 1=Cara,  0=Águila    Frecuencia
#              1          155
#              0          157
# 1=Cara,  0=Águila    Frecuencia
#              1          155
#              0          158
# 1=Cara,  0=Águila    Frecuencia
#              1          155
#              0          159
# 1=Cara,  0=Águila    Frecuencia
#              1          156
#              0          159
# 1=Cara,  0=Águila    Frecuencia
#              1          156
#              0          160
# 1=Cara,  0=Águila    Frecuencia
#              1          156
#              0          161
# 1=Cara,  0=Águila    Frecuencia
#              1          156
#              0          162
# 1=Cara,  0=Águila    Frecuencia
#              1          157
#              0          162
# 1=Cara,  0=Águila    Frecuencia
#              1          158
#              0          162
# 1=Cara,  0=Águila    Frecuencia
#              1          158
#              0          163
# 1=Cara,  0=Águila    Frecuencia
#              1          158
#              0          164
# 1=Cara,  0=Águila    Frecuencia
#              1          158
#              0          165
# 1=Cara,  0=Águila    Frecuencia
#              1          158
#              0          166
# 1=Cara,  0=Águila    Frecuencia
#              1          159
#              0          166
# 1=Cara,  0=Águila    Frecuencia
#              1          159
#              0          167
# 1=Cara,  0=Águila    Frecuencia
#              1          159
#              0          168
# 1=Cara,  0=Águila    Frecuencia
#              1          159
#              0          169
# 1=Cara,  0=Águila    Frecuencia
#              1          159
#              0          170
# 1=Cara,  0=Águila    Frecuencia
#              1          159
#              0          171
# 1=Cara,  0=Águila    Frecuencia
#              1          159
#              0          172
# 1=Cara,  0=Águila    Frecuencia
#              1          160
#              0          172
# 1=Cara,  0=Águila    Frecuencia
#              1          161
#              0          172
# 1=Cara,  0=Águila    Frecuencia
#              1          161
#              0          173
# 1=Cara,  0=Águila    Frecuencia
#              1          161
#              0          174
# 1=Cara,  0=Águila    Frecuencia
#              1          162
#              0          174
# 1=Cara,  0=Águila    Frecuencia
#              1          163
#              0          174
# 1=Cara,  0=Águila    Frecuencia
#              1          164
#              0          174
# 1=Cara,  0=Águila    Frecuencia
#              1          164
#              0          175
# 1=Cara,  0=Águila    Frecuencia
#              1          165
#              0          175
# 1=Cara,  0=Águila    Frecuencia
#              1          166
#              0          175
# 1=Cara,  0=Águila    Frecuencia
#              1          166
#              0          176
# 1=Cara,  0=Águila    Frecuencia
#              1          167
#              0          176
# 1=Cara,  0=Águila    Frecuencia
#              1          168
#              0          176
# 1=Cara,  0=Águila    Frecuencia
#              1          168
#              0          177
# 1=Cara,  0=Águila    Frecuencia
#              1          168
#              0          178
# 1=Cara,  0=Águila    Frecuencia
#              1          169
#              0          178
# 1=Cara,  0=Águila    Frecuencia
#              1          170
#              0          178
# 1=Cara,  0=Águila    Frecuencia
#              1          171
#              0          178
# 1=Cara,  0=Águila    Frecuencia
#              1          171
#              0          179
# 1=Cara,  0=Águila    Frecuencia
#              1          172
#              0          179
# 1=Cara,  0=Águila    Frecuencia
#              1          173
#              0          179
# 1=Cara,  0=Águila    Frecuencia
#              1          174
#              0          179
# 1=Cara,  0=Águila    Frecuencia
#              1          174
#              0          180
# 1=Cara,  0=Águila    Frecuencia
#              1          174
#              0          181
# 1=Cara,  0=Águila    Frecuencia
#              1          174
#              0          182
# 1=Cara,  0=Águila    Frecuencia
#              1          174
#              0          183
# 1=Cara,  0=Águila    Frecuencia
#              1          175
#              0          183
# 1=Cara,  0=Águila    Frecuencia
#              1          176
#              0          183
# 1=Cara,  0=Águila    Frecuencia
#              1          176
#              0          184
# 1=Cara,  0=Águila    Frecuencia
#              1          176
#              0          185
# 1=Cara,  0=Águila    Frecuencia
#              1          176
#              0          186
# 1=Cara,  0=Águila    Frecuencia
#              1          176
#              0          187
# 1=Cara,  0=Águila    Frecuencia
#              1          177
#              0          187
# 1=Cara,  0=Águila    Frecuencia
#              1          178
#              0          187
# 1=Cara,  0=Águila    Frecuencia
#              1          179
#              0          187
# 1=Cara,  0=Águila    Frecuencia
#              1          180
#              0          187
# 1=Cara,  0=Águila    Frecuencia
#              1          181
#              0          187
# 1=Cara,  0=Águila    Frecuencia
#              1          182
#              0          187
# 1=Cara,  0=Águila    Frecuencia
#              1          182
#              0          188
# 1=Cara,  0=Águila    Frecuencia
#              1          183
#              0          188
# 1=Cara,  0=Águila    Frecuencia
#              1          184
#              0          188
# 1=Cara,  0=Águila    Frecuencia
#              1          184
#              0          189
# 1=Cara,  0=Águila    Frecuencia
#              1          185
#              0          189
# 1=Cara,  0=Águila    Frecuencia
#              1          186
#              0          189
# 1=Cara,  0=Águila    Frecuencia
#              1          186
#              0          190
# 1=Cara,  0=Águila    Frecuencia
#              1          187
#              0          190
# 1=Cara,  0=Águila    Frecuencia
#              1          187
#              0          191
# 1=Cara,  0=Águila    Frecuencia
#              1          187
#              0          192
# 1=Cara,  0=Águila    Frecuencia
#              1          187
#              0          193
# 1=Cara,  0=Águila    Frecuencia
#              1          187
#              0          194
# 1=Cara,  0=Águila    Frecuencia
#              1          187
#              0          195
# 1=Cara,  0=Águila    Frecuencia
#              1          188
#              0          195
# 1=Cara,  0=Águila    Frecuencia
#              1          189
#              0          195
# 1=Cara,  0=Águila    Frecuencia
#              1          189
#              0          196
# 1=Cara,  0=Águila    Frecuencia
#              1          189
#              0          197
# 1=Cara,  0=Águila    Frecuencia
#              1          190
#              0          197
# 1=Cara,  0=Águila    Frecuencia
#              1          191
#              0          197
# 1=Cara,  0=Águila    Frecuencia
#              1          191
#              0          198
# 1=Cara,  0=Águila    Frecuencia
#              1          192
#              0          198
# 1=Cara,  0=Águila    Frecuencia
#              1          192
#              0          199
# 1=Cara,  0=Águila    Frecuencia
#              1          192
#              0          200
# 1=Cara,  0=Águila    Frecuencia
#              1          192
#              0          201
# 1=Cara,  0=Águila    Frecuencia
#              1          192
#              0          202
# 1=Cara,  0=Águila    Frecuencia
#              1          193
#              0          202
# 1=Cara,  0=Águila    Frecuencia
#              1          193
#              0          203
# 1=Cara,  0=Águila    Frecuencia
#              1          194
#              0          203
# 1=Cara,  0=Águila    Frecuencia
#              1          194
#              0          204
# 1=Cara,  0=Águila    Frecuencia
#              1          194
#              0          205
# 1=Cara,  0=Águila    Frecuencia
#              1          195
#              0          205
# 1=Cara,  0=Águila    Frecuencia
#              1          196
#              0          205
# 1=Cara,  0=Águila    Frecuencia
#              1          196
#              0          206
# 1=Cara,  0=Águila    Frecuencia
#              1          197
#              0          206
# 1=Cara,  0=Águila    Frecuencia
#              1          198
#              0          206
# 1=Cara,  0=Águila    Frecuencia
#              1          198
#              0          207
# 1=Cara,  0=Águila    Frecuencia
#              1          199
#              0          207
# 1=Cara,  0=Águila    Frecuencia
#              1          200
#              0          207
# 1=Cara,  0=Águila    Frecuencia
#              1          201
#              0          207
# 1=Cara,  0=Águila    Frecuencia
#              1          201
#              0          208
# 1=Cara,  0=Águila    Frecuencia
#              1          202
#              0          208
# 1=Cara,  0=Águila    Frecuencia
#              1          202
#              0          209
# 1=Cara,  0=Águila    Frecuencia
#              1          203
#              0          209
# 1=Cara,  0=Águila    Frecuencia
#              1          203
#              0          210
# 1=Cara,  0=Águila    Frecuencia
#              1          204
#              0          210
# 1=Cara,  0=Águila    Frecuencia
#              1          205
#              0          210
# 1=Cara,  0=Águila    Frecuencia
#              1          205
#              0          211
# 1=Cara,  0=Águila    Frecuencia
#              1          206
#              0          211
# 1=Cara,  0=Águila    Frecuencia
#              1          207
#              0          211
# 1=Cara,  0=Águila    Frecuencia
#              1          208
#              0          211
# 1=Cara,  0=Águila    Frecuencia
#              1          209
#              0          211
# 1=Cara,  0=Águila    Frecuencia
#              1          210
#              0          211
# 1=Cara,  0=Águila    Frecuencia
#              1          211
#              0          211
# 1=Cara,  0=Águila    Frecuencia
#              1          212
#              0          211
# 1=Cara,  0=Águila    Frecuencia
#              1          212
#              0          212
# 1=Cara,  0=Águila    Frecuencia
#              1          212
#              0          213
# 1=Cara,  0=Águila    Frecuencia
#              1          213
#              0          213
# 1=Cara,  0=Águila    Frecuencia
#              1          213
#              0          214
# 1=Cara,  0=Águila    Frecuencia
#              1          213
#              0          215
# 1=Cara,  0=Águila    Frecuencia
#              1          213
#              0          216
# 1=Cara,  0=Águila    Frecuencia
#              1          213
#              0          217
# 1=Cara,  0=Águila    Frecuencia
#              1          213
#              0          218
# 1=Cara,  0=Águila    Frecuencia
#              1          213
#              0          219
# 1=Cara,  0=Águila    Frecuencia
#              1          214
#              0          219
# 1=Cara,  0=Águila    Frecuencia
#              1          215
#              0          219
# 1=Cara,  0=Águila    Frecuencia
#              1          216
#              0          219
# 1=Cara,  0=Águila    Frecuencia
#              1          216
#              0          220
# 1=Cara,  0=Águila    Frecuencia
#              1          217
#              0          220
# 1=Cara,  0=Águila    Frecuencia
#              1          217
#              0          221
# 1=Cara,  0=Águila    Frecuencia
#              1          217
#              0          222
# 1=Cara,  0=Águila    Frecuencia
#              1          218
#              0          222
# 1=Cara,  0=Águila    Frecuencia
#              1          218
#              0          223
# 1=Cara,  0=Águila    Frecuencia
#              1          218
#              0          224
# 1=Cara,  0=Águila    Frecuencia
#              1          218
#              0          225
# 1=Cara,  0=Águila    Frecuencia
#              1          218
#              0          226
# 1=Cara,  0=Águila    Frecuencia
#              1          218
#              0          227
# 1=Cara,  0=Águila    Frecuencia
#              1          218
#              0          228
# 1=Cara,  0=Águila    Frecuencia
#              1          218
#              0          229
# 1=Cara,  0=Águila    Frecuencia
#              1          219
#              0          229
# 1=Cara,  0=Águila    Frecuencia
#              1          220
#              0          229
# 1=Cara,  0=Águila    Frecuencia
#              1          220
#              0          230
# 1=Cara,  0=Águila    Frecuencia
#              1          220
#              0          231
# 1=Cara,  0=Águila    Frecuencia
#              1          221
#              0          231
# 1=Cara,  0=Águila    Frecuencia
#              1          222
#              0          231
# 1=Cara,  0=Águila    Frecuencia
#              1          222
#              0          232
# 1=Cara,  0=Águila    Frecuencia
#              1          223
#              0          232
# 1=Cara,  0=Águila    Frecuencia
#              1          223
#              0          233
# 1=Cara,  0=Águila    Frecuencia
#              1          223
#              0          234
# 1=Cara,  0=Águila    Frecuencia
#              1          224
#              0          234
# 1=Cara,  0=Águila    Frecuencia
#              1          224
#              0          235
# 1=Cara,  0=Águila    Frecuencia
#              1          225
#              0          235
# 1=Cara,  0=Águila    Frecuencia
#              1          225
#              0          236
# 1=Cara,  0=Águila    Frecuencia
#              1          226
#              0          236
# 1=Cara,  0=Águila    Frecuencia
#              1          226
#              0          237
# 1=Cara,  0=Águila    Frecuencia
#              1          227
#              0          237
# 1=Cara,  0=Águila    Frecuencia
#              1          227
#              0          238
# 1=Cara,  0=Águila    Frecuencia
#              1          228
#              0          238
# 1=Cara,  0=Águila    Frecuencia
#              1          229
#              0          238
# 1=Cara,  0=Águila    Frecuencia
#              1          229
#              0          239
# 1=Cara,  0=Águila    Frecuencia
#              1          229
#              0          240
# 1=Cara,  0=Águila    Frecuencia
#              1          230
#              0          240
# 1=Cara,  0=Águila    Frecuencia
#              1          230
#              0          241
# 1=Cara,  0=Águila    Frecuencia
#              1          230
#              0          242
# 1=Cara,  0=Águila    Frecuencia
#              1          231
#              0          242
# 1=Cara,  0=Águila    Frecuencia
#              1          231
#              0          243
# 1=Cara,  0=Águila    Frecuencia
#              1          231
#              0          244
# 1=Cara,  0=Águila    Frecuencia
#              1          232
#              0          244
# 1=Cara,  0=Águila    Frecuencia
#              1          232
#              0          245
# 1=Cara,  0=Águila    Frecuencia
#              1          232
#              0          246
# 1=Cara,  0=Águila    Frecuencia
#              1          232
#              0          247
# 1=Cara,  0=Águila    Frecuencia
#              1          233
#              0          247
# 1=Cara,  0=Águila    Frecuencia
#              1          233
#              0          248
# 1=Cara,  0=Águila    Frecuencia
#              1          233
#              0          249
# 1=Cara,  0=Águila    Frecuencia
#              1          234
#              0          249
# 1=Cara,  0=Águila    Frecuencia
#              1          235
#              0          249
# 1=Cara,  0=Águila    Frecuencia
#              1          235
#              0          250
# 1=Cara,  0=Águila    Frecuencia
#              1          236
#              0          250
# 1=Cara,  0=Águila    Frecuencia
#              1          237
#              0          250
# 1=Cara,  0=Águila    Frecuencia
#              1          238
#              0          250
# 1=Cara,  0=Águila    Frecuencia
#              1          239
#              0          250
# 1=Cara,  0=Águila    Frecuencia
#              1          240
#              0          250
# 1=Cara,  0=Águila    Frecuencia
#              1          240
#              0          251
# 1=Cara,  0=Águila    Frecuencia
#              1          241
#              0          251
# 1=Cara,  0=Águila    Frecuencia
#              1          242
#              0          251
# 1=Cara,  0=Águila    Frecuencia
#              1          242
#              0          252
# 1=Cara,  0=Águila    Frecuencia
#              1          243
#              0          252
# 1=Cara,  0=Águila    Frecuencia
#              1          243
#              0          253
# 1=Cara,  0=Águila    Frecuencia
#              1          243
#              0          254
# 1=Cara,  0=Águila    Frecuencia
#              1          243
#              0          255
# 1=Cara,  0=Águila    Frecuencia
#              1          244
#              0          255
# 1=Cara,  0=Águila    Frecuencia
#              1          245
#              0          255
# 1=Cara,  0=Águila    Frecuencia
#              1          245
#              0          256
# 1=Cara,  0=Águila    Frecuencia
#              1          245
#              0          257
# 1=Cara,  0=Águila    Frecuencia
#              1          245
#              0          258
# 1=Cara,  0=Águila    Frecuencia
#              1          245
#              0          259
# 1=Cara,  0=Águila    Frecuencia
#              1          246
#              0          259
# 1=Cara,  0=Águila    Frecuencia
#              1          246
#              0          260
# 1=Cara,  0=Águila    Frecuencia
#              1          247
#              0          260
# 1=Cara,  0=Águila    Frecuencia
#              1          247
#              0          261
# 1=Cara,  0=Águila    Frecuencia
#              1          248
#              0          261
# 1=Cara,  0=Águila    Frecuencia
#              1          249
#              0          261
# 1=Cara,  0=Águila    Frecuencia
#              1          249
#              0          262
# 1=Cara,  0=Águila    Frecuencia
#              1          249
#              0          263
# 1=Cara,  0=Águila    Frecuencia
#              1          249
#              0          264
# 1=Cara,  0=Águila    Frecuencia
#              1          249
#              0          265
# 1=Cara,  0=Águila    Frecuencia
#              1          249
#              0          266
# 1=Cara,  0=Águila    Frecuencia
#              1          249
#              0          267
# 1=Cara,  0=Águila    Frecuencia
#              1          249
#              0          268
# 1=Cara,  0=Águila    Frecuencia
#              1          249
#              0          269
# 1=Cara,  0=Águila    Frecuencia
#              1          250
#              0          269
# 1=Cara,  0=Águila    Frecuencia
#              1          251
#              0          269
# 1=Cara,  0=Águila    Frecuencia
#              1          251
#              0          270
# 1=Cara,  0=Águila    Frecuencia
#              1          251
#              0          271
# 1=Cara,  0=Águila    Frecuencia
#              1          251
#              0          272
# 1=Cara,  0=Águila    Frecuencia
#              1          252
#              0          272
# 1=Cara,  0=Águila    Frecuencia
#              1          253
#              0          272
# 1=Cara,  0=Águila    Frecuencia
#              1          253
#              0          273
# 1=Cara,  0=Águila    Frecuencia
#              1          254
#              0          273
# 1=Cara,  0=Águila    Frecuencia
#              1          254
#              0          274
# 1=Cara,  0=Águila    Frecuencia
#              1          255
#              0          274
# 1=Cara,  0=Águila    Frecuencia
#              1          255
#              0          275
# 1=Cara,  0=Águila    Frecuencia
#              1          255
#              0          276
# 1=Cara,  0=Águila    Frecuencia
#              1          255
#              0          277
# 1=Cara,  0=Águila    Frecuencia
#              1          256
#              0          277
# 1=Cara,  0=Águila    Frecuencia
#              1          257
#              0          277
# 1=Cara,  0=Águila    Frecuencia
#              1          258
#              0          277
# 1=Cara,  0=Águila    Frecuencia
#              1          259
#              0          277
# 1=Cara,  0=Águila    Frecuencia
#              1          259
#              0          278
# 1=Cara,  0=Águila    Frecuencia
#              1          259
#              0          279
# 1=Cara,  0=Águila    Frecuencia
#              1          259
#              0          280
# 1=Cara,  0=Águila    Frecuencia
#              1          260
#              0          280
# 1=Cara,  0=Águila    Frecuencia
#              1          260
#              0          281
# 1=Cara,  0=Águila    Frecuencia
#              1          260
#              0          282
# 1=Cara,  0=Águila    Frecuencia
#              1          261
#              0          282
# 1=Cara,  0=Águila    Frecuencia
#              1          261
#              0          283
# 1=Cara,  0=Águila    Frecuencia
#              1          262
#              0          283
# 1=Cara,  0=Águila    Frecuencia
# ...
#              1         4946
#              0         4873
# 1=Cara,  0=Águila    Frecuencia
#              1         4947
#              0         4873
# 1=Cara,  0=Águila    Frecuencia
#              1         4948
#              0         4873
# 1=Cara,  0=Águila    Frecuencia
#              1         4948
#              0         4874
# 1=Cara,  0=Águila    Frecuencia
#              1         4948
#              0         4875
# 1=Cara,  0=Águila    Frecuencia
#              1         4948
#              0         4876
# 1=Cara,  0=Águila    Frecuencia
#              1         4949
#              0         4876
# 1=Cara,  0=Águila    Frecuencia
#              1         4949
#              0         4877
# 1=Cara,  0=Águila    Frecuencia
#              1         4949
#              0         4878
# 1=Cara,  0=Águila    Frecuencia
#              1         4950
#              0         4878
# 1=Cara,  0=Águila    Frecuencia
#              1         4951
#              0         4878
# 1=Cara,  0=Águila    Frecuencia
#              1         4952
#              0         4878
# 1=Cara,  0=Águila    Frecuencia
#              1         4953
#              0         4878
# 1=Cara,  0=Águila    Frecuencia
#              1         4954
#              0         4878
# 1=Cara,  0=Águila    Frecuencia
#              1         4955
#              0         4878
# 1=Cara,  0=Águila    Frecuencia
#              1         4955
#              0         4879
# 1=Cara,  0=Águila    Frecuencia
#              1         4956
#              0         4879
# 1=Cara,  0=Águila    Frecuencia
#              1         4956
#              0         4880
# 1=Cara,  0=Águila    Frecuencia
#              1         4956
#              0         4881
# 1=Cara,  0=Águila    Frecuencia
#              1         4956
#              0         4882
# 1=Cara,  0=Águila    Frecuencia
#              1         4956
#              0         4883
# 1=Cara,  0=Águila    Frecuencia
#              1         4957
#              0         4883
# 1=Cara,  0=Águila    Frecuencia
#              1         4957
#              0         4884
# 1=Cara,  0=Águila    Frecuencia
#              1         4958
#              0         4884
# 1=Cara,  0=Águila    Frecuencia
#              1         4958
#              0         4885
# 1=Cara,  0=Águila    Frecuencia
#              1         4959
#              0         4885
# 1=Cara,  0=Águila    Frecuencia
#              1         4959
#              0         4886
# 1=Cara,  0=Águila    Frecuencia
#              1         4959
#              0         4887
# 1=Cara,  0=Águila    Frecuencia
#              1         4960
#              0         4887
# 1=Cara,  0=Águila    Frecuencia
#              1         4961
#              0         4887
# 1=Cara,  0=Águila    Frecuencia
#              1         4961
#              0         4888
# 1=Cara,  0=Águila    Frecuencia
#              1         4962
#              0         4888
# 1=Cara,  0=Águila    Frecuencia
#              1         4963
#              0         4888
# 1=Cara,  0=Águila    Frecuencia
#              1         4964
#              0         4888
# 1=Cara,  0=Águila    Frecuencia
#              1         4965
#              0         4888
# 1=Cara,  0=Águila    Frecuencia
#              1         4965
#              0         4889
# 1=Cara,  0=Águila    Frecuencia
#              1         4966
#              0         4889
# 1=Cara,  0=Águila    Frecuencia
#              1         4967
#              0         4889
# 1=Cara,  0=Águila    Frecuencia
#              1         4967
#              0         4890
# 1=Cara,  0=Águila    Frecuencia
#              1         4968
#              0         4890
# 1=Cara,  0=Águila    Frecuencia
#              1         4968
#              0         4891
# 1=Cara,  0=Águila    Frecuencia
#              1         4969
#              0         4891
# 1=Cara,  0=Águila    Frecuencia
#              1         4969
#              0         4892
# 1=Cara,  0=Águila    Frecuencia
#              1         4970
#              0         4892
# 1=Cara,  0=Águila    Frecuencia
#              1         4970
#              0         4893
# 1=Cara,  0=Águila    Frecuencia
#              1         4971
#              0         4893
# 1=Cara,  0=Águila    Frecuencia
#              1         4971
#              0         4894
# 1=Cara,  0=Águila    Frecuencia
#              1         4971
#              0         4895
# 1=Cara,  0=Águila    Frecuencia
#              1         4972
#              0         4895
# 1=Cara,  0=Águila    Frecuencia
#              1         4972
#              0         4896
# 1=Cara,  0=Águila    Frecuencia
#              1         4972
#              0         4897
# 1=Cara,  0=Águila    Frecuencia
#              1         4973
#              0         4897
# 1=Cara,  0=Águila    Frecuencia
#              1         4973
#              0         4898
# 1=Cara,  0=Águila    Frecuencia
#              1         4974
#              0         4898
# 1=Cara,  0=Águila    Frecuencia
#              1         4975
#              0         4898
# 1=Cara,  0=Águila    Frecuencia
#              1         4976
#              0         4898
# 1=Cara,  0=Águila    Frecuencia
#              1         4976
#              0         4899
# 1=Cara,  0=Águila    Frecuencia
#              1         4977
#              0         4899
# 1=Cara,  0=Águila    Frecuencia
#              1         4977
#              0         4900
# 1=Cara,  0=Águila    Frecuencia
#              1         4977
#              0         4901
# 1=Cara,  0=Águila    Frecuencia
#              1         4977
#              0         4902
# 1=Cara,  0=Águila    Frecuencia
#              1         4977
#              0         4903
# 1=Cara,  0=Águila    Frecuencia
#              1         4977
#              0         4904
# 1=Cara,  0=Águila    Frecuencia
#              1         4977
#              0         4905
# 1=Cara,  0=Águila    Frecuencia
#              1         4978
#              0         4905
# 1=Cara,  0=Águila    Frecuencia
#              1         4979
#              0         4905
# 1=Cara,  0=Águila    Frecuencia
#              1         4979
#              0         4906
# 1=Cara,  0=Águila    Frecuencia
#              1         4979
#              0         4907
# 1=Cara,  0=Águila    Frecuencia
#              1         4980
#              0         4907
# 1=Cara,  0=Águila    Frecuencia
#              1         4981
#              0         4907
# 1=Cara,  0=Águila    Frecuencia
#              1         4982
#              0         4907
# 1=Cara,  0=Águila    Frecuencia
#              1         4982
#              0         4908
# 1=Cara,  0=Águila    Frecuencia
#              1         4983
#              0         4908
# 1=Cara,  0=Águila    Frecuencia
#              1         4983
#              0         4909
# 1=Cara,  0=Águila    Frecuencia
#              1         4983
#              0         4910
# 1=Cara,  0=Águila    Frecuencia
#              1         4984
#              0         4910
# 1=Cara,  0=Águila    Frecuencia
#              1         4985
#              0         4910
# 1=Cara,  0=Águila    Frecuencia
#              1         4986
#              0         4910
# 1=Cara,  0=Águila    Frecuencia
#              1         4987
#              0         4910
# 1=Cara,  0=Águila    Frecuencia
#              1         4987
#              0         4911
# 1=Cara,  0=Águila    Frecuencia
#              1         4988
#              0         4911
# 1=Cara,  0=Águila    Frecuencia
#              1         4989
#              0         4911
# 1=Cara,  0=Águila    Frecuencia
#              1         4989
#              0         4912
# 1=Cara,  0=Águila    Frecuencia
#              1         4990
#              0         4912
# 1=Cara,  0=Águila    Frecuencia
#              1         4990
#              0         4913
# 1=Cara,  0=Águila    Frecuencia
#              1         4990
#              0         4914
# 1=Cara,  0=Águila    Frecuencia
#              1         4990
#              0         4915
# 1=Cara,  0=Águila    Frecuencia
#              1         4990
#              0         4916
# 1=Cara,  0=Águila    Frecuencia
#              1         4991
#              0         4916
# 1=Cara,  0=Águila    Frecuencia
#              1         4991
#              0         4917
# 1=Cara,  0=Águila    Frecuencia
#              1         4991
#              0         4918
# 1=Cara,  0=Águila    Frecuencia
#              1         4992
#              0         4918
# 1=Cara,  0=Águila    Frecuencia
#              1         4992
#              0         4919
# 1=Cara,  0=Águila    Frecuencia
#              1         4993
#              0         4919
# 1=Cara,  0=Águila    Frecuencia
#              1         4994
#              0         4919
# 1=Cara,  0=Águila    Frecuencia
#              1         4995
#              0         4919
# 1=Cara,  0=Águila    Frecuencia
#              1         4996
#              0         4919
# 1=Cara,  0=Águila    Frecuencia
#              1         4996
#              0         4920
# 1=Cara,  0=Águila    Frecuencia
#              1         4997
#              0         4920
# 1=Cara,  0=Águila    Frecuencia
#              1         4997
#              0         4921
# 1=Cara,  0=Águila    Frecuencia
#              1         4997
#              0         4922
# 1=Cara,  0=Águila    Frecuencia
#              1         4997
#              0         4923
# 1=Cara,  0=Águila    Frecuencia
#              1         4997
#              0         4924
# 1=Cara,  0=Águila    Frecuencia
#              1         4998
#              0         4924
# 1=Cara,  0=Águila    Frecuencia
#              1         4998
#              0         4925
# 1=Cara,  0=Águila    Frecuencia
#              1         4999
#              0         4925
# 1=Cara,  0=Águila    Frecuencia
#              1         5000
#              0         4925
# 1=Cara,  0=Águila    Frecuencia
#              1         5000
#              0         4926
# 1=Cara,  0=Águila    Frecuencia
#              1         5000
#              0         4927
# 1=Cara,  0=Águila    Frecuencia
#              1         5000
#              0         4928
# 1=Cara,  0=Águila    Frecuencia
#              1         5000
#              0         4929
# 1=Cara,  0=Águila    Frecuencia
#              1         5000
#              0         4930
# 1=Cara,  0=Águila    Frecuencia
#              1         5001
#              0         4930
# 1=Cara,  0=Águila    Frecuencia
#              1         5001
#              0         4931
# 1=Cara,  0=Águila    Frecuencia
#              1         5002
#              0         4931
# 1=Cara,  0=Águila    Frecuencia
#              1         5002
#              0         4932
# 1=Cara,  0=Águila    Frecuencia
#              1         5002
#              0         4933
# 1=Cara,  0=Águila    Frecuencia
#              1         5003
#              0         4933
# 1=Cara,  0=Águila    Frecuencia
#              1         5003
#              0         4934
# 1=Cara,  0=Águila    Frecuencia
#              1         5003
#              0         4935
# 1=Cara,  0=Águila    Frecuencia
#              1         5004
#              0         4935
# 1=Cara,  0=Águila    Frecuencia
#              1         5004
#              0         4936
# 1=Cara,  0=Águila    Frecuencia
#              1         5004
#              0         4937
# 1=Cara,  0=Águila    Frecuencia
#              1         5004
#              0         4938
# 1=Cara,  0=Águila    Frecuencia
#              1         5004
#              0         4939
# 1=Cara,  0=Águila    Frecuencia
#              1         5005
#              0         4939
# 1=Cara,  0=Águila    Frecuencia
#              1         5005
#              0         4940
# 1=Cara,  0=Águila    Frecuencia
#              1         5005
#              0         4941
# 1=Cara,  0=Águila    Frecuencia
#              1         5006
#              0         4941
# 1=Cara,  0=Águila    Frecuencia
#              1         5006
#              0         4942
# 1=Cara,  0=Águila    Frecuencia
#              1         5007
#              0         4942
# 1=Cara,  0=Águila    Frecuencia
#              1         5008
#              0         4942
# 1=Cara,  0=Águila    Frecuencia
#              1         5008
#              0         4943
# 1=Cara,  0=Águila    Frecuencia
#              1         5008
#              0         4944
# 1=Cara,  0=Águila    Frecuencia
#              1         5008
#              0         4945
# 1=Cara,  0=Águila    Frecuencia
#              1         5008
#              0         4946
# 1=Cara,  0=Águila    Frecuencia
#              1         5008
#              0         4947
# 1=Cara,  0=Águila    Frecuencia
#              1         5009
#              0         4947
# 1=Cara,  0=Águila    Frecuencia
#              1         5009
#              0         4948
# 1=Cara,  0=Águila    Frecuencia
#              1         5009
#              0         4949
# 1=Cara,  0=Águila    Frecuencia
#              1         5010
#              0         4949
# 1=Cara,  0=Águila    Frecuencia
#              1         5011
#              0         4949
# 1=Cara,  0=Águila    Frecuencia
#              1         5012
#              0         4949
# 1=Cara,  0=Águila    Frecuencia
#              1         5012
#              0         4950
# 1=Cara,  0=Águila    Frecuencia
#              1         5013
#              0         4950
# 1=Cara,  0=Águila    Frecuencia
#              1         5013
#              0         4951
# 1=Cara,  0=Águila    Frecuencia
#              1         5013
#              0         4952
# 1=Cara,  0=Águila    Frecuencia
#              1         5013
#              0         4953
# 1=Cara,  0=Águila    Frecuencia
#              1         5014
#              0         4953
# 1=Cara,  0=Águila    Frecuencia
#              1         5014
#              0         4954
# 1=Cara,  0=Águila    Frecuencia
#              1         5014
#              0         4955
# 1=Cara,  0=Águila    Frecuencia
#              1         5014
#              0         4956
# 1=Cara,  0=Águila    Frecuencia
#              1         5014
#              0         4957
# 1=Cara,  0=Águila    Frecuencia
#              1         5014
#              0         4958
# 1=Cara,  0=Águila    Frecuencia
#              1         5015
#              0         4958
# 1=Cara,  0=Águila    Frecuencia
#              1         5016
#              0         4958
# 1=Cara,  0=Águila    Frecuencia
#              1         5017
#              0         4958
# 1=Cara,  0=Águila    Frecuencia
#              1         5018
#              0         4958
# 1=Cara,  0=Águila    Frecuencia
#              1         5018
#              0         4959
# 1=Cara,  0=Águila    Frecuencia
#              1         5019
#              0         4959
# 1=Cara,  0=Águila    Frecuencia
#              1         5020
#              0         4959
# 1=Cara,  0=Águila    Frecuencia
#              1         5020
#              0         4960
# 1=Cara,  0=Águila    Frecuencia
#              1         5021
#              0         4960
# 1=Cara,  0=Águila    Frecuencia
#              1         5021
#              0         4961
# 1=Cara,  0=Águila    Frecuencia
#              1         5021
#              0         4962
# 1=Cara,  0=Águila    Frecuencia
#              1         5022
#              0         4962
# 1=Cara,  0=Águila    Frecuencia
#              1         5022
#              0         4963
# 1=Cara,  0=Águila    Frecuencia
#              1         5023
#              0         4963
# 1=Cara,  0=Águila    Frecuencia
#              1         5023
#              0         4964
# 1=Cara,  0=Águila    Frecuencia
#              1         5024
#              0         4964
# 1=Cara,  0=Águila    Frecuencia
#              1         5025
#              0         4964
# 1=Cara,  0=Águila    Frecuencia
#              1         5026
#              0         4964
# 1=Cara,  0=Águila    Frecuencia
#              1         5026
#              0         4965
# 1=Cara,  0=Águila    Frecuencia
#              1         5027
#              0         4965
# 1=Cara,  0=Águila    Frecuencia
#              1         5027
#              0         4966
# 1=Cara,  0=Águila    Frecuencia
#              1         5028
#              0         4966
# 1=Cara,  0=Águila    Frecuencia
#              1         5029
#              0         4966
# 1=Cara,  0=Águila    Frecuencia
#              1         5030
#              0         4966
# 1=Cara,  0=Águila    Frecuencia
#              1         5031
#              0         4966
# 1=Cara,  0=Águila    Frecuencia
#              1         5031
#              0         4967
# 1=Cara,  0=Águila    Frecuencia
#              1         5032
#              0         4967
# 1=Cara,  0=Águila    Frecuencia
#              1         5033
#              0         4967

# %% [markdown]
# Si queremos obligar a que random sieeeempre nos de los mismos resultados, podemos usar seed. Arma una semilla de 25 y ejecuta el código 2 veces, checa como se repita (seed necesita repetirse 2 veces tmb)

# %%
random.seed(1)
for tirada in range(10):
    print(random.randrange(0, 2), end=" ")
# Out:
# 0 0 1 0 1 1 1 1 0 0

# %%
random.seed(21)
for tirada in range(10):
    print(random.randrange(0, 2), end=" ")
# Out:
# 0 1 1 1 1 0 1 0 0 0

# %% [markdown]
# Es momento de jugar a "El Gran 8".
#
# Lo primero será lanzar un par de dados - arma una función que simule 2 dados y devuelva los valores que cayeron

# %%
import random

def lanzar_dados():
    dado1 = random.randrange(1,7)
    dado2 = random.randrange(1,7)
    return(dado1, dado2)

def mostrar_dados(dado):
    dado1, dado2 = dado
    print(f'Resultado de la jugada: {dado1} + {dado2} = {dado1 + dado2}')

valores_logrados = lanzar_dados()
mostrar_dados(valores_logrados)
suma_dados = sum(valores_logrados)

if suma_dados == 8:    # Cambiado de 'in (8)' a '== 8'
    status_jugador = 'Ganaste'
elif suma_dados == 7:
    status_jugador = 'Perdiste'
else:
    status_jugador = 'Continuar'
    print('sigue probando, encuentra el Gran 8')

while status_jugador == 'Continuar':
    valores_logrados = lanzar_dados()
    mostrar_dados(valores_logrados)
    suma_dados = sum(valores_logrados)
    if suma_dados in (6,8):
        status_jugador = 'Ganaste'
    elif suma_dados == 7:
        status_jugador = 'Perdiste'
    if status_jugador == 'Ganaste':
        print('Ganaste')
    else:
        print('Perdiste')
# Out:
# Resultado de la jugada: 4 + 6 = 10
# sigue probando, encuentra el Gran 8
# Resultado de la jugada: 4 + 5 = 9
# Perdiste
# Resultado de la jugada: 4 + 1 = 5
# Perdiste
# Resultado de la jugada: 3 + 5 = 8
# Ganaste

# %% [markdown]
# Ahora arma una función que muestre la suma de los resultados de los 2 dados

# %%
def suma_dados(dado):
    dado1, dado2 = dado
    suma = dado1 + dado2
    print(f'La suma de los dados es: {suma}')
    return suma

valores_logrados = lanzar_dados()
mostrar_dados(valores_logrados)
resultado_suma = suma_dados(valores_logrados)
# Out:
# Resultado de la jugada: 1 + 4 = 5
# La suma de los dados es: 5

# %% [markdown]
# Ahora necesitamos una variable que almacene el resutlado de lanzar los dados (funcion 1) y otra que sume los resultados de la función 1.

# %%
resultado_lanzamiento = lanzar_dados()
mostrar_dados(resultado_lanzamiento)
total_dados = sum(resultado_lanzamiento)

print(f"Los dados que salieron fueron: {resultado_lanzamiento}")
print(f"La suma total es: {total_dados}")
# Out:
# Resultado de la jugada: 2 + 5 = 7
# Los dados que salieron fueron: (2, 5)
# La suma total es: 7

# %% [markdown]
# Ahora, vamos  a simular las consecuencias del primer tiro - si la suma es 8, ganaste, si es 7, perdiste, y si no, continuamos

# %%
resultado_lanzamiento = lanzar_dados()
mostrar_dados(resultado_lanzamiento)
total_dados = sum(resultado_lanzamiento)

if total_dados == 8:
    print("¡Ganaste en el primer tiro!")
    status_jugador = "Ganaste"
elif total_dados == 7:
    print("¡Perdiste en el primer tiro!")
    status_jugador = "Perdiste"
else:
    print("¡Sigue jugando! Busca el Gran 8")
    status_jugador = "Continuar"
# Out:
# Resultado de la jugada: 4 + 4 = 8
# ¡Ganaste en el primer tiro!

# %% [markdown]
# Y ahora con un bucle vamos a seguir el juego, se relanzan los dados y si se hace un bucle while que mientras que no haya un resultado de 6,8, o 7, se sigue tirando, si no se define si se ganó o se perdió

# %%
resultado_lanzamiento = lanzar_dados()
mostrar_dados(resultado_lanzamiento)
total_dados = sum(resultado_lanzamiento)

if total_dados == 8:
    print("¡Ganaste en el primer tiro!")
    status_jugador = "Ganaste"
elif total_dados == 7:
    print("¡Perdiste en el primer tiro!")
    status_jugador = "Perdiste"
else:
    print("¡Sigue jugando! Busca el Gran 8")
    status_jugador = "Continuar"


while status_jugador == "Continuar":
    resultado_lanzamiento = lanzar_dados()
    mostrar_dados(resultado_lanzamiento)
    total_dados = sum(resultado_lanzamiento)
    
    if total_dados in (6, 8, 7):
        print("¡Ganaste!")
        status_jugador = "Ganaste"
    elif total_dados == 7:
        print("¡Perdiste!")
        status_jugador = "Perdiste"
    else:
        print("¡Sigue intentando conseguir un 6 u 8!")
# Out:
# Resultado de la jugada: 4 + 5 = 9
# ¡Sigue jugando! Busca el Gran 8
# Resultado de la jugada: 4 + 3 = 7
# ¡Ganaste!

# %% [markdown]
# Ahora unifica todo el código

# %% [markdown]
# #### Por tu cuenta
#
# Usa un bucle for, randrange y una expresión condicional para simular 20 tiros de moneda, mosrando A para águila y S para Sello

# %%
import random

for _ in range(20):
    print('A' if random.randrange(2) == 0  else 'S', end=' ')
# Out:
# S S S A A A S A S S A S S A S S S S S A

# %% [markdown]
# ## 4.5.- Funciones sin parámetros y múltiples parámetros

# %% [markdown]
# def raizcuadra(numero):
#     """Esta función saca la raiz cuadra de un número"""
#     return numero ** (1/2)Se acuerdan de la primer funcion que hicimos? Que pasa si la corremos sin parametro?

# %%
def raiz_cuad(numero):

    return numero ** (1/2)

raiz_cuad(49)
# Out:
# 7.0

# %%
raiz_cuad()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 raiz_cuad()
#
# TypeError: raiz_cuad() missing 1 required positional argument: 'numero'

# %% [markdown]
# Asigna un parametro estandar para evitar este error

# %% [markdown]
# También, hay funciones que pueden aceptar una cantidad indefinida de parametros - arma una función llamada promedio_calif que te diga el promedio de una cantidad arbitraria de calificaciones

# %%
def raiz_cuad(numero=1):

    return numero ** (1/2)

raiz_cuad()

raiz_cuad(27)
# Out:
# 5.196152422706632

# %%
def promedio_calif(*calif):
    return sum(calif)/len(calif)

promedio_calif(9,8,8,9.5,9.7,10,6)

promedio_calif(7,7.3,8.1)
# Out:
# 7.466666666666666

# %% [markdown]
# #### Por tu cuenta
#
# Arma una función que reciba una cantidad arbitraria de argumentos y calcule el producto de multiplicarlos todos entre ellos

# %%
def multiplicar(*numeros):
    resultado = 1
    for n in numeros:
        resultado = resultado * n
    
    return resultado

# Ejemplo de uso:
print(multiplicar(2, 3, 4))
# Out:
# 24

# %%
def multiplicar(*numeros):
    resultado = 1
    for n in numeros:
        resultado = resultado * n
    
    return resultado

# Ejemplo de uso:
print(multiplicar(5,6,7))
# Out:
# 210

# %% [markdown]
# ## 4.6.- Alcance Local y Global

# %% [markdown]
# Recordemos nuestra función de raiz cuadrada

# %%
def raiz_cuad(numero = 1):
    return numero ** (1/2)
raiz_cuad(64)
# Out:
# 8.0

# %%
aprox_pi = 3.141

def acceso_global_pi():
    print('aprox pi es llamada de acceso_global_pi como:', aprox_pi)

acceso_global_pi
# Out:
# <function __main__.acceso_global_pi()>

# %%
def intento_modificar_global_pi():
    aprox_pi = 3.1416
    print('Modificación de aprox_pi como:' , aprox_pi)
aprox_pi
# Out:
# 3.141

# %% [markdown]
# Define la variable aprox pi =3.141 y luego define una función que llame a esta variable de acceso global

# %% [markdown]
# Intenta modificar aprox pi desde una función - verás que python no lo hace, solo modifica una copia

# %% [markdown]
# ## 4.7.- El módulo de matemáticas de Python

# %% [markdown]
# Calcula el log10 de 1000

# %%
log10(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 log10(100)
#
# NameError: name 'log10' is not defined

# %% [markdown]
# Importa la librería math

# %%
import math

# %% [markdown]
# ahora si, calcula el log10 de 1000

# %%
math.log10(100)
# Out:
# 2.0

# %% [markdown]
# ## 4.8.- Medidas de tendencia central y Dispersión

# %% [markdown]
# Importa la librería d eestadistica, y crea una lista de calificaciones aleatorias entre 50 y 100

# %%
import statistics as estad

calificaciones = [68,90,80,100,80,75,85,95,70,70]

media=estad.mean(calificaciones)
mediana=estad.median(calificaciones)
moda=estad.mode(calificaciones)

rango = max(calificaciones) - min(calificaciones)
varianza = estad.variance(calificaciones)
desv_estandar = estad.stdev(calificaciones)

print('Las medidas de tendencia central son:')
print(f'Media: {media: > 7}')
print(f'Mediana: {mediana: > 5}')
print(f'Moda: {moda: > 6}')

print('Las medidas de dispersión son:')
print(f'Rango: {rango: > 2}')
print(f'Varianza: {varianza: > 0.3f}')
print(f'Desviación estándar: {desv_estandar: > 0.3f}')
# Out:
# Las medidas de tendencia central son:
# Media:    81.3
# Mediana:  80.0
# Moda:     80
# Las medidas de dispersión son:
# Rango:  32
# Varianza:  122.456
# Desviación estándar:  11.066

# %% [markdown]
# Calcula las medidas de tendencia central

# %% [markdown]
# Calcula las medidas de dispersión

# %% [markdown]
# #### Por tu cuenta
#
# Para los numeros del 1 al 20, calcula la varianza y la desviacion estandar - compara con la varianza poblacional y la desviacion estandar poblacional

# %%
import statistics as estad

numeros = list(range(1, 21))

varianza_muestral = estad.variance(numeros)
desv_muestral = estad.stdev(numeros)

varianza_poblacional = estad.pvariance(numeros)
desv_poblacional = estad.pstdev(numeros)

print("Varianza muestral:           ", varianza_muestral)
print("Desviación estándar muestral:", desv_muestral)
print("Varianza poblacional:        ", varianza_poblacional)
print("Desviación estándar poblacional:", desv_poblacional)
# Out:
# Varianza muestral:            35
# Desviación estándar muestral: 5.916079783099616
# Varianza poblacional:         33.25
# Desviación estándar poblacional: 5.766281297335398
